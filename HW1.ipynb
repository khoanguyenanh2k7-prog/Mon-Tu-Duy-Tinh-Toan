# %% [markdown]
# ##Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này.

# %%
s = input()
print (s[4], s[8])
# Out:
# f g

# %% [markdown]
# ##Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
a,b,c= map(float, input().split())
if a+b>c and a+c>b and b+c>a:
    print("Dien tich cua tam giac la: ", ((a+b+c)/2*(a+b+c-2*a)*(a+b+c-2*b)*(a+b+c-2*c))**0.5)
else:
    print("Khong phai la 3 canh cua tam giac")
# Out:
# Khong phai la 3 canh cua tam giac

# %% [markdown]
# ##Bai5:Nhập vào chữ cái hoa A
# ###in ra chữ cái thường liền trước chữ cái a thường tương ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
c = input()
if c == 'A':
    print ('z')
else:
    print (chr(ord(c.lower())-1))
# Out:
# a

# %% [markdown]
# ##Bai4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường).
# ###Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c} không phải là kí tự alphabet.

# %%
c = input()
if c.isupper():
    print (f"{c} la ki tu alphabet")
else:
    print (f"{c} khong la ki tu alphabet")
# Out:
# C la ki tu alphabet

# %% [markdown]
# ##Bai3:Viết chương trình nhập vào một “kí tự” c
# ###nếu Nó là chữ hoa thì in ra chữ thường tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem trước cấu trúc lựa chọn: if….else, ma)

# %%
c = input()
if c.isupper():
    print (c.lower())
else:
    print (c.upper())
# Out:
# 1 2 3

# %% [markdown]
# ##Bai2:Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu
# vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b.
# ###ãy tính phần diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân.

# %%
a,b= map(float, input().split())
print(f"{a*b-(a/2**2*3.14):.2f}")
# Out:
# 1.21

# %% [markdown]
# ##Bai1:Nhap vao 1 so nguyen
# ###In ra man hinh so gap doi cua n

# %%
n = int(input())
print (n*2)
# Out:
# 6
